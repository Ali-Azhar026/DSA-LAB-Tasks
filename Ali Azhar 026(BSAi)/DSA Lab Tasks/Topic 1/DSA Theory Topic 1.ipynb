# %% [markdown]
# # ¬@Task 1
# ##  Analyzing Time Complexity of Algorithms

# %% [markdown]
# ## #1

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2
    left_half = merge_sort(arr[:mid])
    right_half = merge_sort(arr[mid:])
    
    return merge(left_half, right_half)

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    
    result.extend(left[i:])
    result.extend(right[j:])
    
    return result

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    
    pivot = arr[0]
    less = [x for x in arr[1:] if x <= pivot]
    greater = [x for x in arr[1:] if x > pivot]
    
    return quick_sort(less) + [pivot] + quick_sort(greater)


arr = [64, 34, 25, 12, 22, 11, 90]

print("Bubble Sort:", bubble_sort(arr.copy()))
print("Merge Sort:", merge_sort(arr.copy()))
print("Quick Sort:", quick_sort(arr.copy()))
# Out:
# Bubble Sort: [11, 12, 22, 25, 34, 64, 90]
# Merge Sort: [11, 12, 22, 25, 34, 64, 90]
# Quick Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ## #2

# %%
import random
import time

random_list = [random.randint(1, 10000) for _ in range(1000)]

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2
    left_half = merge_sort(arr[:mid])
    right_half = merge_sort(arr[mid:])
    
    return merge(left_half, right_half)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[0]
    less = [x for x in arr[1:] if x <= pivot]
    greater = [x for x in arr[1:] if x > pivot]
    return quick_sort(less) + [pivot] + quick_sort(greater)
    
for sort_func in [bubble_sort, merge_sort, quick_sort]:
    test_list = random_list.copy()
    start = time.time()
    sorted_list = sort_func(test_list)
    end = time.time()
    print(f"{sort_func.__name__} took {end - start:.4f} seconds")
# Out:
# bubble_sort took 0.1128 seconds
# merge_sort took 0.0000 seconds
# quick_sort took 0.0177 seconds

# %% [markdown]
# ## #3

# %%
import random
import time

random_list = [random.randint(1, 10000) for _ in range(1000)]

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[0]
    less = [x for x in arr[1:] if x <= pivot]
    greater = [x for x in arr[1:] if x > pivot]
    return quick_sort(less) + [pivot] + quick_sort(greater)

execution_times = {}

start = time.time()
bubble_sort(random_list.copy())
execution_times["Bubble Sort"] = time.time() - start

start = time.time()
merge_sort(random_list.copy())
execution_times["Merge Sort"] = time.time() - start

start = time.time()
quick_sort(random_list.copy())
execution_times["Quick Sort"] = time.time() - start

for algo, t in execution_times.items():
    print(f"{algo} took {t:.4f} seconds")
# Out:
# Bubble Sort took 0.1326 seconds
# Merge Sort took 0.0000 seconds
# Quick Sort took 0.0000 seconds

# %% [markdown]
# ## #4

# %%
import random
import time
import matplotlib.pyplot as plt

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[0]
    less = [x for x in arr[1:] if x <= pivot]
    greater = [x for x in arr[1:] if x > pivot]
    return quick_sort(less) + [pivot] + quick_sort(greater)

sizes = [100, 200, 300, 400, 500]
bubble_times = []
merge_times = []
quick_times = []

for size in sizes:
    test_data = [random.randint(1, 10000) for _ in range(size)]
    
    start = time.time()
    bubble_sort(test_data.copy())
    bubble_times.append(time.time() - start)
    
    start = time.time()
    merge_sort(test_data.copy())
    merge_times.append(time.time() - start)
    
    start = time.time()
    quick_sort(test_data.copy())
    quick_times.append(time.time() - start)

plt.figure(figsize=(10, 6))
plt.plot(sizes, bubble_times, label='Bubble Sort (O(n²))', marker='o')
plt.plot(sizes, merge_times, label='Merge Sort (O(n log n))', marker='o')
plt.plot(sizes, quick_times, label='Quick Sort (O(n log n))', marker='o')
plt.title('Sorting Algorithm Time Complexity Comparison')
plt.xlabel('Input Size (n)')
plt.ylabel('Execution Time (seconds)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ¬@Task 2
# ##  Recursive vs Iterative Approach

# %% [markdown]
# ## #1

# %%
def fibonacci_recursive(n):
    if n <= 1:
        return n
    return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)

def fibonacci_iterative(n):
    if n <= 1:
        return n
    a, b = 0, 1
    for _ in range(2, n + 1):
        a, b = b, a + b
    return b

n = 10
print("Recursive:", fibonacci_recursive(n))
print("Iterative:", fibonacci_iterative(n))
# Out:
# Recursive: 55
# Iterative: 55

# %% [markdown]
# ## #2

# %%
import time

def fibonacci_recursive(n):
    if n <= 1:
        return n
    return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)

def fibonacci_iterative(n):
    if n <= 1:
        return n
    a, b = 0, 1
    for _ in range(2, n + 1):
        a, b = b, a + b
    return b

# Test values
test_values = [10, 20, 30, 40]
print(f"{'n':>5} | {'Recursive Time (s)':>20} | {'Iterative Time (s)':>20}")
print("-" * 52)

for n in test_values:
    start = time.time()
    fibonacci_recursive(n)
    recursive_time = time.time() - start

    start = time.time()
    fibonacci_iterative(n)
    iterative_time = time.time() - start

    print(f"{n:>5} | {recursive_time:>20.6f} | {iterative_time:>20.6f}")
# Out:
#     n |   Recursive Time (s) |   Iterative Time (s)
# ----------------------------------------------------
#    10 |             0.000000 |             0.000000
#    20 |             0.002148 |             0.000000
#    30 |             0.333298 |             0.000000
#    40 |            40.129620 |             0.000000

# %% [markdown]
# ## #3

# %%
from functools import lru_cache

@lru_cache(maxsize=None)
def fibonacci_recursive_memo(n):
    if n <= 1:
        return n
    return fibonacci_recursive_memo(n - 1) + fibonacci_recursive_memo(n - 2)

def fibonacci_recursive_manual(n, memo={}):
    if n in memo:
        return memo[n]
    if n <= 1:
        memo[n] = n
    else:
        memo[n] = fibonacci_recursive_manual(n - 1, memo) + fibonacci_recursive_manual(n - 2, memo)
    return memo[n]

print(fibonacci_recursive_memo(40))         
print(fibonacci_recursive_manual(40))
# Out:
# 102334155
# 102334155

# %% [markdown]
# ## #4

# %%
import time
import matplotlib.pyplot as plt
from functools import lru_cache

# Naive Recursive Fibonacci (O(2^n))
def fibonacci_recursive(n):
    if n <= 1:
        return n
    return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)

@lru_cache(maxsize=None)
def fibonacci_recursive_memo(n):
    if n <= 1:
        return n
    return fibonacci_recursive_memo(n - 1) + fibonacci_recursive_memo(n - 2)

def fibonacci_iterative(n):
    if n <= 1:
        return n
    a, b = 0, 1
    for _ in range(2, n + 1):
        a, b = b, a + b
    return b

test_values = [10, 20, 25, 30, 35, 40]
timings = {"Recursive": [], "Memoized Recursive": [], "Iterative": []}

for n in test_values:
    start = time.time()
    fibonacci_recursive(n)
    timings["Recursive"].append(time.time() - start)

    start = time.time()
    fibonacci_recursive_memo(n)
    timings["Memoized Recursive"].append(time.time() - start)

    start = time.time()
    fibonacci_iterative(n)
    timings["Iterative"].append(time.time() - start)

plt.figure(figsize=(10, 6))
plt.plot(test_values, timings["Recursive"], label="Naive Recursive (O(2^n))", marker='o')
plt.plot(test_values, timings["Memoized Recursive"], label="Memoized Recursive (O(n))", marker='o')
plt.plot(test_values, timings["Iterative"], label="Iterative (O(n))", marker='o')

plt.title("Fibonacci Performance Comparison")
plt.xlabel("n (Fibonacci Index)")
plt.ylabel("Execution Time (seconds)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

for i, n in enumerate(test_values):
    print(f"n = {n}")
    print(f"  Naive Recursive: {timings['Recursive'][i]:.6f} seconds")
    print(f"  Memoized Recursive: {timings['Memoized Recursive'][i]:.6f} seconds")
    print(f"  Iterative: {timings['Iterative'][i]:.6f} seconds")
# Out:
# n = 10
#   Naive Recursive: 0.000000 seconds
#   Memoized Recursive: 0.000000 seconds
#   Iterative: 0.000000 seconds
# n = 20
#   Naive Recursive: 0.004683 seconds
#   Memoized Recursive: 0.000000 seconds
#   Iterative: 0.000000 seconds
# n = 25
#   Naive Recursive: 0.054932 seconds
#   Memoized Recursive: 0.000000 seconds
#   Iterative: 0.000000 seconds
# n = 30
#   Naive Recursive: 0.314386 seconds
#   Memoized Recursive: 0.000000 seconds
#   Iterative: 0.000000 seconds
# n = 35
#   Naive Recursive: 3.876497 seconds
#   Memoized Recursive: 0.000000 seconds
#   Iterative: 0.000000 seconds
# n = 40
#   Naive Recursive: 44.117903 seconds
#   Memoized Recursive: 0.000000 seconds
#   Iterative: 0.000000 seconds

# %% [markdown]
# # ¬@Task 3
# ## Visualizing Big-O Notation

# %% [markdown]
# ## #1

# %%
def constant_time_example(lst):
    return lst[0] 

def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1 

def linear_time_example(lst):
    total = 0
    for item in lst:  
        total += item
    return total


def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2 
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:  
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr


def fibonacci_exponential(n):
    if n <= 1:
        return n
    return fibonacci_exponential(n - 1) + fibonacci_exponential(n - 2)

print("Constant Time Example:")
print(constant_time_example([10, 20, 30]))  

print("\nBinary Search:")
sorted_list = [1, 3, 5, 7, 9, 11]
print(binary_search(sorted_list, 7))  
print(binary_search(sorted_list, 4))  

print("\nLinear Time Example:")
print(linear_time_example([1, 2, 3, 4, 5])) 

print("\nMerge Sort:")
merge_list = [38, 27, 43, 3, 9, 82, 10]
merge_sort(merge_list)
print(merge_list)  

print("\nBubble Sort:")
bubble_list = [64, 34, 25, 12, 22, 11, 90]
sorted_bubble = bubble_sort(bubble_list)
print(sorted_bubble)  

print("\nFibonacci Exponential:")
print(fibonacci_exponential(6))
# Out:
# Constant Time Example:
# 10
#
# Binary Search:
# 3
# -1
#
# Linear Time Example:
# 15
#
# Merge Sort:
# [3, 9, 10, 27, 38, 43, 82]
#
# Bubble Sort:
# [11, 12, 22, 25, 34, 64, 90]
#
# Fibonacci Exponential:
# 8

# %% [markdown]
# ## #2

# %%
import time
import math

# O(1) - Constant time complexity
def constant_time_example(n):
    return 42  # Just a constant value (no operation depending on n)

# O(log n) - Logarithmic time complexity
def log_time_example(n):
    return math.log(n)  # Logarithmic operation (returns the logarithm of n)

# O(n) - Linear time complexity
def linear_time_example(n):
    total = 0
    for i in range(n):
        total += i
    return total  # Sum of all numbers from 0 to n-1

# O(n log n) - Linearithmic time complexity
def n_log_n_time_example(n):
    return sorted(range(n))  # Sorting operation (O(n log n))

# O(n^2) - Quadratic time complexity
def quadratic_time_example(n):
    count = 0
    for i in range(n):
        for j in range(n):
            count += 1
    return count  # Counting pairs (nested loops)

# O(2^n) - Exponential time complexity (only works for small n)
def exponential_time_example(n):
    if n <= 1:
        return n
    return exponential_time_example(n - 1) + exponential_time_example(n - 2)

# Testing function to measure execution time
def measure_execution_times():
    input_sizes = list(range(1, 1001))  # Input sizes from 1 to 1000
    results = {
        "Constant": [],
        "Logarithmic": [],
        "Linear": [],
        "N Log N": [],
        "Quadratic": [],
        "Exponential": []
    }

    for n in input_sizes:
        # Time the O(1) function (constant time)
        start_time = time.time()
        constant_time_example(n)
        results["Constant"].append(time.time() - start_time)

        # Time the O(log n) function (logarithmic time)
        start_time = time.time()
        log_time_example(n)
        results["Logarithmic"].append(time.time() - start_time)

        # Time the O(n) function (linear time)
        start_time = time.time()
        linear_time_example(n)
        results["Linear"].append(time.time() - start_time)

        # Time the O(n log n) function (n log n time)
        start_time = time.time()
        n_log_n_time_example(n)
        results["N Log N"].append(time.time() - start_time)

        # Time the O(n^2) function (quadratic time)
        start_time = time.time()
        quadratic_time_example(n)
        results["Quadratic"].append(time.time() - start_time)

        # Time the O(2^n) function (exponential time)
        # For large n, this may take too long, so we only run it for smaller n (e.g., n <= 20)
        if n <= 20:
            start_time = time.time()
            exponential_time_example(n)
            results["Exponential"].append(time.time() - start_time)
        else:
            results["Exponential"].append(None)  # Mark as None for large n to avoid long runtimes

    return input_sizes, results

# Measure and plot the results
input_sizes, results = measure_execution_times()

import matplotlib.pyplot as plt

# Plotting the execution times
plt.figure(figsize=(12, 8))

# Plot each time complexity
plt.plot(input_sizes, results["Constant"], label="O(1) - Constant", marker='o', linestyle='--')
plt.plot(input_sizes, results["Logarithmic"], label="O(log n) - Logarithmic", marker='o')
plt.plot(input_sizes, results["Linear"], label="O(n) - Linear", marker='o')
plt.plot(input_sizes, results["N Log N"], label="O(n log n) - N Log N", marker='o')
plt.plot(input_sizes, results["Quadratic"], label="O(n²) - Quadratic", marker='o')

# Exponential complexity will be plotted only for smaller input sizes
plt.plot(input_sizes[:21], results["Exponential"][:21], label="O(2^n) - Exponential", marker='o', linestyle=':')

# Labels and title
plt.title('Execution Time for Different Time Complexities')
plt.xlabel('Input Size (n)')
plt.ylabel('Execution Time (seconds)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Print the results for each complexity type
for complexity in results:
    print(f"{complexity}:")
    for n, time_taken in zip(input_sizes, results[complexity]):
        print(f"  n = {n}: {time_taken:.6e} seconds")
# Out:
# Constant:
#   n = 1: 0.000000e+00 seconds
#   n = 2: 0.000000e+00 seconds
#   n = 3: 0.000000e+00 seconds
#   n = 4: 0.000000e+00 seconds
#   n = 5: 0.000000e+00 seconds
#   n = 6: 0.000000e+00 seconds
#   n = 7: 0.000000e+00 seconds
#   n = 8: 0.000000e+00 seconds
#   n = 9: 0.000000e+00 seconds
#   n = 10: 0.000000e+00 seconds
#   n = 11: 0.000000e+00 seconds
#   n = 12: 0.000000e+00 seconds
#   n = 13: 0.000000e+00 seconds
#   n = 14: 0.000000e+00 seconds
#   n = 15: 0.000000e+00 seconds
#   n = 16: 0.000000e+00 seconds
#   n = 17: 0.000000e+00 seconds
#   n = 18: 0.000000e+00 seconds
#   n = 19: 0.000000e+00 seconds
#   n = 20: 0.000000e+00 seconds
#   n = 21: 0.000000e+00 seconds
#   n = 22: 0.000000e+00 seconds
#   n = 23: 0.000000e+00 seconds
#   n = 24: 0.000000e+00 seconds
#   n = 25: 0.000000e+00 seconds
#   n = 26: 0.000000e+00 seconds
#   n = 27: 0.000000e+00 seconds
#   n = 28: 0.000000e+00 seconds
#   n = 29: 0.000000e+00 seconds
#   n = 30: 0.000000e+00 seconds
# ...

# %% [markdown]
# ## #3

# %%
def get_first_element(arr):
    return arr[0]

def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

def sum_elements(arr):
    total = 0
    for num in arr:
        total += num
    return total


def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1
        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr


def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr


def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)
